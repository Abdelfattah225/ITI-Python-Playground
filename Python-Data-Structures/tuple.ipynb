# %%
empty_tuble = ()

numbers = (1,2,3,4,5,"num")

numbers
# Out:
# (1, 2, 3, 4, 5, 'num')

# %%
tuble = (5,)

tuble
# Out:
# (5,)

# %%
tu = 10,20,30

tu
# Out:
# (10, 20, 30)

# %%
another_tuple = tuple([1,2,3])
another_tuple
# Out:
# (1, 2, 3)

# %%
def get_char():
    return (20,30)

x,y = get_char()

x
# Out:
# 20

# %%
# directionary keys
locations = {
    (0,0) : "origin",
    (1,0):  "Point A"
}

locations[(0,0)]
# Out:
# 'origin'

# %%
# protect data 
DAYS_OF_WEEK = ("Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun")
DAYS_OF_WEEK
# Out:
# ('Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun')

# %%
person = ("John", 25, "Engineer")
name , age , job = person

print(name)
print(age)
print(job)
# Out:
# John
# 25
# Engineer

# %%
person = ("John", 25, "Engineer")
newlist = list(person)

newlist
# Out:
# ['John', 25, 'Engineer']
